# %%
from sklearn import datasets
import numpy as np

iris = datasets.load_iris()
X, y = iris.data, iris.target

print(f'{X.shape = }')
print(f'{y.shape = }')
# Out:
# X.shape = (150, 4)
# y.shape = (150,)

# %%
from neural_network.decomposition import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components=2)
X = lda.fit_transform(X, y)

# %%
from neural_network.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f'{X_train.shape = }')
print(f'{y_train.shape = }')
print(f'{X_test.shape = }')
print(f'{y_test.shape = }')
# Out:
# X_train.shape = (105, 2)
# y_train.shape = (105,)
# X_test.shape = (45, 2)
# y_test.shape = (45,)

# %%
from neural_network.preprocess import OneHotEncoder, Scaler

labels = np.unique(y)
encoder = OneHotEncoder().fit(labels)
y_train = encoder.transform(y_train)
y_test = encoder.transform(y_test)
print(f'Encoded {y_train.shape = }')
print(f'Encoded {y_test.shape = }')

scaler, X_train = Scaler().fit_transform(X_train, return_self=True)
X_test = scaler.transform(X_test)
# Out:
# Encoded y_train.shape = (105, 3)
# Encoded y_test.shape = (45, 3)

# %%
from neural_network.layers.dense import Dense
from neural_network.model.sequential import Sequential

net = Sequential()

net.add(
    Dense(10, input_shape=2, activation='relu'),
    Dense(10, activation='tanh'),
    Dense(3, activation='softmax')
)

net.compile(cost='crossentropy', metrics=['accuracy_score'])

# %%
from neural_network.model_selection import KFold

kf = KFold(n_splits=3)

for train, validate in kf.split(X_train):
    net.fit(
        X_train[train],
        y_train[train],
        epochs=10,
        batch_size=5,
        validation_data=(X_train[validate], y_train[validate])
    )
# Out:
# Epoch  1/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#   Step 13/14 ... done
#   Step 14/14 ... done
#
#   Validation loss: 3.8902 accuracy_score: 0.4857
#   Overall loss: 3.4667 accuracy_score: 0.3714
#
# Epoch  2/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 3.3848 accuracy_score: 0.4857
#   Overall loss: 2.6119 accuracy_score: 0.5286
#
# Epoch  3/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 3.0883 accuracy_score: 0.5714
#   Overall loss: 2.2731 accuracy_score: 0.6
#
# Epoch  4/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 2.81 accuracy_score: 0.5714
#   Overall loss: 2.0253 accuracy_score: 0.6429
#
# Epoch  5/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 2.5367 accuracy_score: 0.5714
#   Overall loss: 1.81 accuracy_score: 0.7
#
# Epoch  6/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 2.2551 accuracy_score: 0.5714
#   Overall loss: 1.6104 accuracy_score: 0.7
#
# Epoch  7/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 1.9808 accuracy_score: 0.5714
#   Overall loss: 1.4264 accuracy_score: 0.7143
#
# Epoch  8/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 1.7224 accuracy_score: 0.5714
#   Overall loss: 1.2612 accuracy_score: 0.7286
#
# Epoch  9/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 1.4944 accuracy_score: 0.6
#   Overall loss: 1.119 accuracy_score: 0.7286
#
# Epoch 10/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 1.3044 accuracy_score: 0.6
#   Overall loss: 1.0025 accuracy_score: 0.7286
#
# Epoch  1/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#   Step 13/14 ... done
#   Step 14/14 ... done
#
#   Validation loss: 0.9735 accuracy_score: 0.6857
#   Overall loss: 0.9616 accuracy_score: 0.6429
#
# Epoch  2/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.8929 accuracy_score: 0.6571
#   Overall loss: 0.8702 accuracy_score: 0.6286
#
# Epoch  3/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.8508 accuracy_score: 0.6571
#   Overall loss: 0.8209 accuracy_score: 0.6857
#
# Epoch  4/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.8427 accuracy_score: 0.7143
#   Overall loss: 0.8064 accuracy_score: 0.7857
#
# Epoch  5/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.8227 accuracy_score: 0.7714
#   Overall loss: 0.7828 accuracy_score: 0.8
#
# Epoch  6/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.7958 accuracy_score: 0.7714
#   Overall loss: 0.7514 accuracy_score: 0.8
#
# Epoch  7/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.7734 accuracy_score: 0.7714
#   Overall loss: 0.7257 accuracy_score: 0.8143
#
# Epoch  8/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.7488 accuracy_score: 0.8
#   Overall loss: 0.7032 accuracy_score: 0.8143
#
# Epoch  9/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.7265 accuracy_score: 0.7714
#   Overall loss: 0.6781 accuracy_score: 0.8286
#
# Epoch 10/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.7073 accuracy_score: 0.7143
#   Overall loss: 0.6552 accuracy_score: 0.8429
#
# Epoch  1/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#   Step 13/14 ... done
#   Step 14/14 ... done
#
#   Validation loss: 0.616 accuracy_score: 0.8
#   Overall loss: 0.6709 accuracy_score: 0.8
#
# Epoch  2/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.6061 accuracy_score: 0.8
#   Overall loss: 0.6532 accuracy_score: 0.8143
#
# Epoch  3/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.5904 accuracy_score: 0.8
#   Overall loss: 0.6365 accuracy_score: 0.8429
#
# Epoch  4/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.575 accuracy_score: 0.8
#   Overall loss: 0.6211 accuracy_score: 0.8429
#
# Epoch  5/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.5618 accuracy_score: 0.8
#   Overall loss: 0.6063 accuracy_score: 0.8429
#
# Epoch  6/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.5497 accuracy_score: 0.8
#   Overall loss: 0.5927 accuracy_score: 0.8286
#
# Epoch  7/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.535 accuracy_score: 0.8
#   Overall loss: 0.5801 accuracy_score: 0.8286
#
# Epoch  8/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.523 accuracy_score: 0.8
#   Overall loss: 0.5682 accuracy_score: 0.8286
#
# Epoch  9/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.5136 accuracy_score: 0.8
#   Overall loss: 0.5573 accuracy_score: 0.8286
#
# Epoch 10/10
#   Step  1/14 ... done
#   Step  2/14 ... done
#   Step  3/14 ... done
#   Step  4/14 ... done
#   Step  5/14 ... done
#   Step  6/14 ... done
#   Step  7/14 ... done
#   Step  8/14 ... done
#   Step  9/14 ... done
#   Step 10/14 ... done
#   Step 11/14 ... done
#   Step 12/14 ... done
#
#   Validation loss: 0.5022 accuracy_score: 0.8
#   Overall loss: 0.547 accuracy_score: 0.8286

# %%
predictions = net.predict(X_test, classify=True)

print(f'{predictions.shape = }')
# Out:
# predictions.shape = (45, 3)

# %%
from neural_network.metrics import confusion_matrix
print('Confusion Matrix')
print(confusion_matrix(y_test, predictions))
# Out:
# Confusion Matrix
# [[16  0  0]
#  [ 0  8  2]
#  [ 0  3 16]]

# %%
from neural_network.metrics import accuracy_score
print('Accuracy Score')
print(accuracy_score(y_test, predictions))
# Out:
# Accuracy Score
# 0.8888888888888888

# %%
from neural_network.metrics import accuracy_by_label
print('Accuracy by Label')
print(accuracy_by_label(y_test, predictions))
# Out:
# Accuracy by Label
# [1.         0.72727273 0.88888889]
